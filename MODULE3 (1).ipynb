# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd
import os
import numpy as np  
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/gdrive/My Drive/mod2result23.csv")
df
# Out:
#         Unnamed: 0  Quarter  Year  ...  humidity_x  ArrDelayMinutes  Arrdel15
# 0           462739        2  2016  ...          83              0.0       1.0
# 1           151447        4  2016  ...          73              0.0       0.0
# 2           422729        1  2016  ...          70              0.0       0.0
# 3          1373465        2  2017  ...           9             16.0       1.0
# 4           538614        2  2016  ...          87             58.0       1.0
# ...            ...      ...   ...  ...         ...              ...       ...
# 538601       83343        4  2016  ...          81              5.0       0.0
# 538602        2975        1  2016  ...          79             28.0       1.0
# 538603     1699965        3  2017  ...          52            183.0       1.0
# 538604      492376        2  2016  ...          53             25.0       1.0
# 538605      171081        4  2016  ...          38             19.0       1.0
#
# [538606 rows x 26 columns]

# %%
X=df.loc[df['Arrdel15'] == 1.0]      #selecting only delayed flights 
X
# Out:
#         Unnamed: 0  Quarter  Year  ...  humidity_x  ArrDelayMinutes  Arrdel15
# 0           462739        2  2016  ...          83              0.0       1.0
# 3          1373465        2  2017  ...           9             16.0       1.0
# 4           538614        2  2016  ...          87             58.0       1.0
# 6           664769        2  2016  ...          61             16.0       1.0
# 7           281899        4  2016  ...          22            109.0       1.0
# ...            ...      ...   ...  ...         ...              ...       ...
# 538600      182409        4  2016  ...          85             25.0       1.0
# 538602        2975        1  2016  ...          79             28.0       1.0
# 538603     1699965        3  2017  ...          52            183.0       1.0
# 538604      492376        2  2016  ...          53             25.0       1.0
# 538605      171081        4  2016  ...          38             19.0       1.0
#
# [281521 rows x 26 columns]

# %%
X.drop(columns =['Unnamed: 0'])
# Out:
#         Quarter  Year  Month  ...  humidity_x  ArrDelayMinutes  Arrdel15
# 0             2  2016      4  ...          83              0.0       1.0
# 3             2  2017      4  ...           9             16.0       1.0
# 4             2  2016      5  ...          87             58.0       1.0
# 6             2  2016      6  ...          61             16.0       1.0
# 7             4  2016     12  ...          22            109.0       1.0
# ...         ...   ...    ...  ...         ...              ...       ...
# 538600        4  2016     11  ...          85             25.0       1.0
# 538602        1  2016      1  ...          79             28.0       1.0
# 538603        3  2017      8  ...          52            183.0       1.0
# 538604        2  2016      4  ...          53             25.0       1.0
# 538605        4  2016     11  ...          38             19.0       1.0
#
# [281521 rows x 25 columns]

# %%
Y=X['ArrDelayMinutes']
Y
# Out:
# 0           0.0
# 3          16.0
# 4          58.0
# 6          16.0
# 7         109.0
#           ...
# 538600     25.0
# 538602     28.0
# 538603    183.0
# 538604     25.0
# 538605     19.0
# Name: ArrDelayMinutes, Length: 281521, dtype: float64

# %%
X=X.drop(columns='ArrDelayMinutes')
X=X.drop(columns='Unnamed: 0')

# %%
X
# Out:
#         Quarter  Year  Month  ...  WindChillF_x  humidity_x  Arrdel15
# 0             2  2016      4  ...            52          83       1.0
# 3             2  2017      4  ...            88           9       1.0
# 4             2  2016      5  ...            54          87       1.0
# 6             2  2016      6  ...            69          61       1.0
# 7             4  2016     12  ...            71          22       1.0
# ...         ...   ...    ...  ...           ...         ...       ...
# 538600        4  2016     11  ...            53          85       1.0
# 538602        1  2016      1  ...            54          79       1.0
# 538603        3  2017      8  ...            93          52       1.0
# 538604        2  2016      4  ...            53          53       1.0
# 538605        4  2016     11  ...            55          38       1.0
#
# [281521 rows x 24 columns]

# %%
X.describe
# Out:
# <bound method NDFrame.describe of         Quarter  Year  Month  ...  WindChillF_x  humidity_x  Arrdel15
# 0             2  2016      4  ...            52          83       1.0
# 3             2  2017      4  ...            88           9       1.0
# 4             2  2016      5  ...            54          87       1.0
# 6             2  2016      6  ...            69          61       1.0
# 7             4  2016     12  ...            71          22       1.0
# ...         ...   ...    ...  ...           ...         ...       ...
# 538600        4  2016     11  ...            53          85       1.0
# 538602        1  2016      1  ...            54          79       1.0
# 538603        3  2017      8  ...            93          52       1.0
# 538604        2  2016      4  ...            53          53       1.0
# 538605        4  2016     11  ...            55          38       1.0
#
# [281521 rows x 24 columns]>

# %% [markdown]
# # **Regression**

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_predlinear=reg.predict(X_test)

# %%
preddf = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_predlinear})

# %%
preddf
# Out:
#         Actual   Predicted
# 99245     22.0   18.443808
# 396364    69.0   83.159578
# 60411     10.0   12.818352
# 282228    22.0   22.396253
# 195191    77.0   83.002056
# ...        ...         ...
# 184745   110.0  114.375898
# 79987     35.0   19.948306
# 68818     18.0   15.803996
# 10903    312.0  324.336361
# 435482    87.0  102.563176
#
# [70381 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predlinear)))
print("MAE : " , mean_absolute_error(Y_test, Y_predlinear))
print("R2   :" , r2_score(Y_test,Y_predlinear))
# Out:
# RMSE : 17.72573653940024
# MAE :  12.39383455930973
# R2   : 0.9408333681256912

# %% [markdown]
# **EXTRA TREES REGRESSION**

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(X_train,Y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
Y_predetr= etr.predict(X_test)

# %%
print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predetr)))
print("MAE : " , mean_absolute_error(Y_test, Y_predetr))
print("R2   :" , r2_score(Y_test,Y_predetr))
# Out:
# RMSE : 12.828238820742936
# MAE :  6.650205495801424
# R2   : 0.9690113725942819

# %%
preddf = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_predetr})
preddf
# Out:
#         Actual  Predicted
# 99245     22.0      22.00
# 396364    69.0      82.70
# 60411     10.0      17.67
# 282228    22.0      22.00
# 195191    77.0      77.00
# ...        ...        ...
# 184745   110.0     114.81
# 79987     35.0      31.37
# 68818     18.0      18.00
# 10903    312.0     331.39
# 435482    87.0     109.60
#
# [70381 rows x 2 columns]

# %% [markdown]
# **XGBOOST REGRESSION**

# %%
import xgboost as xgb
xgbmodel = xgb.XGBRegressor()
xgbmodel.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [09:03:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
Y_predxgbr = xgbmodel.predict(X_test)

# %%
print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predxgbr)))
print("MAE : " , mean_absolute_error(Y_test, Y_predxgbr))
print("R2   :" , r2_score(Y_test,Y_predxgbr))
# Out:
# RMSE : 17.275945111289275
# MAE :  11.978419581415016
# R2   : 0.9437979834715069

# %% [markdown]
# **full dataframe**

# %%
dfmerge = pd.read_csv("/content/gdrive/My Drive/finalmerge.csv",index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
dfmerge
# Out:
#          Unnamed: 0_x  FlightDate  Quarter  ...  WindChillF_y  humidity_y  time_y
# 0                  57  2016-01-01        1  ...            29          66     700
# 1              219870  2016-01-01        1  ...            29          66     700
# 2              356730  2016-01-01        1  ...            29          66     700
# 3              334974  2016-01-01        1  ...            29          66     700
# 4              356750  2016-01-01        1  ...            29          66     700
# ...               ...         ...      ...  ...           ...         ...     ...
# 1815400        453453  2017-09-18        3  ...            69          92    2200
# 1815401        455805  2017-09-21        3  ...            72          75    2200
# 1815402        456636  2017-09-22        3  ...            71          63    2200
# 1815403        457242  2017-09-23        3  ...            86          55    2100
# 1815404        458172  2017-09-24        3  ...            74          87    2200
#
# [1815405 rows x 50 columns]

# %%
dfmergenew=dfmerge.loc[dfmerge['ArrDel15'] ==1.0]      #selecting only delayed flights 
dfmergenew
# Out:
#          Unnamed: 0_x  FlightDate  Quarter  ...  WindChillF_y  humidity_y  time_y
# 6              356840  2016-01-01        1  ...            29          66     700
# 7              145879  2016-01-01        1  ...            29          66     700
# 12              37814  2016-01-01        1  ...            79          81    1300
# 13                887  2016-01-01        1  ...            78          83    1300
# 36             221121  2016-01-01        1  ...            13          88    1200
# ...               ...         ...      ...  ...           ...         ...     ...
# 1815378        414558  2017-09-08        3  ...            86          70    1800
# 1815379        413458  2017-09-08        3  ...            82          84     600
# 1815385        441434  2017-09-03        3  ...            68          86    2300
# 1815395        449441  2017-09-13        3  ...            71          93    2200
# 1815401        455805  2017-09-21        3  ...            72          75    2200
#
# [379366 rows x 50 columns]

# %%
X=dfmergenew.drop([
               "ArrDelayMinutes",
                "ArrTime",
                "ArrDel15",
                  "Unnamed: 0_x",
                  "Unnamed: 0_y",
                  "Unnamed: 0.1",
                "Origin",
                "Dest",
                "airport_x",
                "airport_y",
                "FlightDate",
                "date_y",
                "date_x",
                "time_x",
                "time_y",
                "windspeedKmph_y",
                "winddirDegree_y",
                "weatherCode_y",
                "precipMM_y",
                "visibility_y",
                "pressure_y",
                "cloudcover_y",
                "DewPointF_y",
                "WindGustKmph_y",
                "tempF_y",
               "WindChillF_y",
               "humidity_y",],axis=1)
X
# Out:
#          Quarter  Year  Month  ...  tempF_x  WindChillF_x  humidity_x
# 6              1  2016      1  ...       29            21          56
# 7              1  2016      1  ...       35            25          70
# 12             1  2016      1  ...       51            49          73
# 13             1  2016      1  ...       41            32          74
# 36             1  2016      1  ...       47            41          50
# ...          ...   ...    ...  ...      ...           ...         ...
# 1815378        3  2017      9  ...       77            77          55
# 1815379        3  2017      9  ...       65            65          83
# 1815385        3  2017      9  ...       83            83          61
# 1815395        3  2017      9  ...       66            66          93
# 1815401        3  2017      9  ...       65            65          91
#
# [379366 rows x 23 columns]

# %%
Y=dfmergenew['ArrDelayMinutes']
Y
# Out:
# 6           37.0
# 7           24.0
# 12          51.0
# 13          25.0
# 36          22.0
#            ...
# 1815378     49.0
# 1815379    279.0
# 1815385     68.0
# 1815395     33.0
# 1815401     51.0
# Name: ArrDelayMinutes, Length: 379366, dtype: float64

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20)

# %% [markdown]
# **linear regression**

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,Y_train)

Y_predlinear=reg.predict(X_test)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predlinear)))
print("MAE : " , mean_absolute_error(Y_test, Y_predlinear))
print("R2   :" , r2_score(Y_test,Y_predlinear))
# Out:
# RMSE : 17.675157430816448
# MAE :  12.248745923438115
# R2   : 0.9404281149942026

# %% [markdown]
# **extra trees**

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(X_train,Y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
Y_pred_etr_test = etr.predict(X_test)

# %%
print("RMSE  " , np.sqrt(mean_squared_error(Y_test, Y_pred_etr_test)))
print("MAE   " , mean_absolute_error(Y_test, Y_pred_etr_test))
print("R2    " , r2_score(Y_test,Y_pred_etr_test))
# Out:
# RMSE   16.992303734196998
# MAE    11.895361849909058
# R2     0.9449421452287274

# %% [markdown]
# **XGB**

# %%
import xgboost as xgb
xgbmodel = xgb.XGBRegressor()
xgbmodel.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [09:14:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
Y_predxgbr = xgbmodel.predict(X_test)

# %%
print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predxgbr)))
print("MAE : " , mean_absolute_error(Y_test, Y_predxgbr))
print("R2   :" , r2_score(Y_test,Y_predxgbr))
# Out:
# RMSE : 17.071781466706806
# MAE :  11.712980522573863
# R2   : 0.9444258989196301
