# %%
import pandas as pd
from pandas import np
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## **Pipeline**

# %%
df = pd.read_csv("/content/gdrive/My Drive/mod2result15.csv",index_col=0)
df
# Out:
#          Quarter  Year  Month  ...  humidity_x  ArrDelayMinutes  Arrdel15
# 1558696        2  2017      6  ...          59              0.0       0.0
# 1501578        2  2017      5  ...          12             17.0       0.0
# 369946         1  2016      3  ...          51              1.0       0.0
# 1484669        2  2017      5  ...          75              0.0       0.0
# 461826         2  2016      4  ...          79              0.0       0.0
# ...          ...   ...    ...  ...         ...              ...       ...
# 417875         1  2016      3  ...          85              9.0       0.0
# 1098467        4  2017     11  ...          63              0.0       0.0
# 982429         1  2017      1  ...          66              0.0       0.0
# 113599         4  2016     10  ...          77              0.0       0.0
# 1062769        4  2017     10  ...          28              0.0       0.0
#
# [544622 rows x 25 columns]

# %%
X=df.loc[df['Arrdel15'] == 1.0]      #selecting only delayed flights 
X.shape
Y = X['ArrDelayMinutes']
Y
# Out:
# 1551709    179.0
# 1216387     37.0
# 1296978     13.0
# 1057972    393.0
# 1376633      0.0
#            ...
# 375148       9.0
# 1202612    201.0
# 1262797     57.0
# 1638758    148.0
# 840665      31.0
# Name: ArrDelayMinutes, Length: 104175, dtype: float64

# %%
X.shape
# Out:
# (104175, 25)

# %%
X=X.drop(['ArrDelayMinutes','Arrdel15'],axis = 1)

# %%
X
# Out:
#          Quarter  Year  Month  ...  tempF_x  WindChillF_x  humidity_x
# 1551709        2  2017      6  ...       76            78          46
# 1216387        1  2017      2  ...       39            35          86
# 1296978        1  2017      3  ...       87            84          18
# 1057972        4  2017     10  ...       57            54          58
# 1376633        2  2017      4  ...       59            60          84
# ...          ...   ...    ...  ...      ...           ...         ...
# 375148         1  2016      3  ...       38            34          92
# 1202612        4  2017     12  ...       47            47          96
# 1262797        1  2017      2  ...       65            64          43
# 1638758        3  2017      7  ...       85            85          80
# 840665         3  2016      8  ...       86            87          29
#
# [104175 rows x 23 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# **Linear Regression**

# %%
Y_predlinear=reg.predict(X)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print("RMSE :" , np.sqrt(mean_squared_error(Y, Y_predlinear)))
print("MAE : " , mean_absolute_error(Y, Y_predlinear))
print("R2   :" , r2_score(Y,Y_predlinear))
# Out:
# RMSE : 18.810409570180653
# MAE :  13.96336944231368
# R2   : 0.9416735213852827
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   import sys

# %%
preddf = pd.DataFrame({'Actual': Y, 'Predicted': Y_predlinear})
preddf
# Out:
#          Actual   Predicted
# 1551709   179.0  162.712451
# 1216387    37.0   46.275129
# 1296978    13.0   12.659862
# 1057972   393.0  385.156757
# 1376633     0.0   15.038984
# ...         ...         ...
# 375148      9.0   19.799363
# 1202612   201.0  196.517733
# 1262797    57.0   47.722615
# 1638758   148.0  156.551073
# 840665     31.0   44.148288
#
# [104175 rows x 2 columns]

# %%
X_train.shape
# Out:
# (265556, 23)

# %% [markdown]
# **EXTRATREES**

# %%
Y_pred_etr_test = etr.predict(X)
print("RMSE  " , np.sqrt(mean_squared_error(Y, Y_pred_etr_test)))
print("MAE   " , mean_absolute_error(Y, Y_pred_etr_test))
print("R2    " , r2_score(Y,Y_pred_etr_test))
# Out:
# RMSE   14.105748983683522
# MAE    7.616091384689225
# R2     0.9672009280148665
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %%
preddfe = pd.DataFrame({'Actual': Y, 'Predicted': Y_pred_etr_test})
preddfe
# Out:
#          Actual  Predicted
# 1551709   179.0     179.00
# 1216387    37.0      37.00
# 1296978    13.0      22.01
# 1057972   393.0     393.00
# 1376633     0.0      29.47
# ...         ...        ...
# 375148      9.0      18.30
# 1202612   201.0     201.00
# 1262797    57.0      57.00
# 1638758   148.0     148.00
# 840665     31.0      30.38
#
# [104175 rows x 2 columns]

# %% [markdown]
# **XGB Regressor**

# %%
Y_predxgbr = xgbmodel.predict(X)
print("RMSE :" , np.sqrt(mean_squared_error(Y, Y_predxgbr)))
print("MAE : " , mean_absolute_error(Y, Y_predxgbr))
print("R2   :" , r2_score(Y,Y_predxgbr))
# Out:
# RMSE : 19.142597250402034
# MAE :  14.422276831146965
# R2   : 0.9395952657634615
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %%
preddfx = pd.DataFrame({'Actual': Y, 'Predicted': Y_predxgbr})
preddfx
# Out:
#          Actual   Predicted
# 1551709   179.0  161.342606
# 1216387    37.0   42.397263
# 1296978    13.0   25.960157
# 1057972   393.0  381.762238
# 1376633     0.0   26.864098
# ...         ...         ...
# 375148      9.0   23.830578
# 1202612   201.0  199.495178
# 1262797    57.0   41.985115
# 1638758   148.0  155.414963
# 840665     31.0   43.153191
#
# [104175 rows x 2 columns]

# %% [markdown]
# **Full DataFrame**

# %%
dfmerge = pd.read_csv("/content/gdrive/My Drive/finalmerge.csv",index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
dfmergenew=dfmerge.loc[dfmerge['ArrDel15'] ==1.0]      #selecting only delayed flights 
#dfmergenew
Y=dfmergenew['ArrDelayMinutes']
Y
# Out:
# 6           37.0
# 7           24.0
# 12          51.0
# 13          25.0
# 36          22.0
#            ...
# 1815378     49.0
# 1815379    279.0
# 1815385     68.0
# 1815395     33.0
# 1815401     51.0
# Name: ArrDelayMinutes, Length: 379366, dtype: float64

# %%
X=dfmergenew.drop([
               "ArrDelayMinutes",
                "ArrTime",
                "ArrDel15",
                  "Unnamed: 0_x",
                  "Unnamed: 0_y",
                  "Unnamed: 0.1",
                "Origin",
                "Dest",
                "airport_x",
                "airport_y",
                "FlightDate",
                "date_y",
                "date_x",
                "time_x",
                "time_y",
                "windspeedKmph_y",
                "winddirDegree_y",
                "weatherCode_y",
                "precipMM_y",
                "visibility_y",
                "pressure_y",
                "cloudcover_y",
                "DewPointF_y",
                "WindGustKmph_y",
                "tempF_y",
               "WindChillF_y",
               "humidity_y",
               ],axis=1)
X
# Out:
#          Quarter  Year  Month  ...  tempF_x  WindChillF_x  humidity_x
# 6              1  2016      1  ...       29            21          56
# 7              1  2016      1  ...       35            25          70
# 12             1  2016      1  ...       51            49          73
# 13             1  2016      1  ...       41            32          74
# 36             1  2016      1  ...       47            41          50
# ...          ...   ...    ...  ...      ...           ...         ...
# 1815378        3  2017      9  ...       77            77          55
# 1815379        3  2017      9  ...       65            65          83
# 1815385        3  2017      9  ...       83            83          61
# 1815395        3  2017      9  ...       66            66          93
# 1815401        3  2017      9  ...       65            65          91
#
# [379366 rows x 23 columns]

# %%
#Y=dfmergenew['ArrDelayMinutes']
#Y

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.30)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (265556, 23)
# (265556,)
# (113810, 23)
# (113810,)

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,Y_train)

Y_predlinear=reg.predict(X_test)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predlinear)))
print("MAE : " , mean_absolute_error(Y_test, Y_predlinear))
print("R2   :" , r2_score(Y_test,Y_predlinear))
# Out:
# RMSE : 17.549614817357206
# MAE :  12.204148062904785
# R2   : 0.9383032593389817
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# **Extra Trees Regressor**

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor(n_jobs=-1,random_state =None)
etr.fit(X_train,Y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
Y_predetr= etr.predict(X_test)
print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predetr)))
print("MAE : " , mean_absolute_error(Y_test, Y_predetr))
print("R2   :" , r2_score(Y_test,Y_predetr))
# Out:
# RMSE : 16.830278233934234
# MAE :  11.880292285387927
# R2   : 0.9432573472955313
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %% [markdown]
# **XGB**

# %%
import xgboost as xgb
xgbmodel = xgb.XGBRegressor()
xgbmodel.fit(X_train,Y_train)
Y_predxgbr = xgbmodel.predict(X_test)
print("RMSE :" , np.sqrt(mean_squared_error(Y_test, Y_predxgbr)))
print("MAE : " , mean_absolute_error(Y_test, Y_predxgbr))
print("R2   :" , r2_score(Y_test,Y_predxgbr))
# Out:
# [11:53:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE : 16.861254612510468
# MAE :  11.673614598116613
# R2   : 0.9430482836797036
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """
