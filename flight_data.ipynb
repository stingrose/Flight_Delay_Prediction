# %%
import os
import pandas as pd
import glob
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import glob
('/content/gdrive/My Drive/2016')
df = pd.concat(map(pd.read_csv, glob.glob('/content/gdrive/My Drive/2016/*.csv')))
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (48,69,76,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
df
# Out:
#         Year  Quarter  Month  ...  Div5WheelsOff  Div5TailNum Unnamed: 109
# 0       2016        1      1  ...            NaN          NaN          NaN
# 1       2016        1      1  ...            NaN          NaN          NaN
# 2       2016        1      1  ...            NaN          NaN          NaN
# 3       2016        1      1  ...            NaN          NaN          NaN
# 4       2016        1      1  ...            NaN          NaN          NaN
# ...      ...      ...    ...  ...            ...          ...          ...
# 454873  2016        3      9  ...            NaN          NaN          NaN
# 454874  2016        3      9  ...            NaN          NaN          NaN
# 454875  2016        3      9  ...            NaN          NaN          NaN
# 454876  2016        3      9  ...            NaN          NaN          NaN
# 454877  2016        3      9  ...            NaN          NaN          NaN
#
# [5617658 rows x 110 columns]

# %%
df1=df[['FlightDate',
'Quarter',
'Year',
'Month',
'DayofMonth',
'DepTime',
'DepDel15',
'CRSDepTime',
'DepDelayMinutes',
'OriginAirportID',
'DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes','Origin','Dest']]

# %%
df2=df1.loc[df1['Origin'].isin([
        'ATL',
        'CLT',
        'DEN',
        'DFW',
        'EWR',
        'IAH',
        'JFK',
        'LAS',
        'LAX',
        'MCO',
        'MIA',
        'ORD',
        'PHX',
        'SEA',
        'SFO'
        ])]

df3_2016=df2.loc[df2['Dest'].isin(['ATL',
        'CLT',
        'DEN',
        'DFW',
        'EWR',
        'IAH',
        'JFK',
        'LAS',
        'LAX',
        'MCO',
        'MIA',
        'ORD',
        'PHX',
        'SEA',
        'SFO'])]

# %%
df3_2016
# Out:
#         FlightDate  Quarter  Year  Month  ...  ArrDel15  ArrDelayMinutes  Origin  Dest
# 57      2016-01-01        1  2016      1  ...       0.0              8.0     SEA   JFK
# 58      2016-01-02        1  2016      1  ...       0.0             11.0     SEA   JFK
# 59      2016-01-03        1  2016      1  ...       0.0              0.0     SEA   JFK
# 60      2016-01-04        1  2016      1  ...       0.0              0.0     SEA   JFK
# 61      2016-01-05        1  2016      1  ...       0.0              0.0     SEA   JFK
# ...            ...      ...   ...    ...  ...       ...              ...     ...   ...
# 454867  2016-09-01        3  2016      9  ...       0.0              0.0     ORD   PHX
# 454868  2016-09-01        3  2016      9  ...       0.0              0.0     MCO   EWR
# 454870  2016-09-01        3  2016      9  ...       0.0              0.0     IAH   LAS
# 454873  2016-09-01        3  2016      9  ...       0.0              0.0     EWR   IAH
# ...

# %% [markdown]
# **2017**

# %%
('/content/gdrive/My Drive/2016')
df = pd.concat(map(pd.read_csv, glob.glob('/content/gdrive/My Drive/2017/*.csv')))
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (48,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1=df[['FlightDate',
'Quarter',
'Year',
'Month',
'DayofMonth',
'DepTime',
'DepDel15',
'CRSDepTime',
'DepDelayMinutes',
'OriginAirportID',
'DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes','Origin','Dest']]

df2=df1.loc[df1['Origin'].isin([
        'ATL',
        'CLT',
        'DEN',
        'DFW',
        'EWR',
        'IAH',
        'JFK',
        'LAS',
        'LAX',
        'MCO',
        'MIA',
        'ORD',
        'PHX',
        'SEA',
        'SFO'
        ])]

df3_2017=df2.loc[df2['Dest'].isin(['ATL',
        'CLT',
        'DEN',
        'DFW',
        'EWR',
        'IAH',
        'JFK',
        'LAS',
        'LAX',
        'MCO',
        'MIA',
        'ORD',
        'PHX',
        'SEA',
        'SFO'])]

# %%
df3_2017
# Out:
#         FlightDate  Quarter  Year  Month  ...  ArrDel15  ArrDelayMinutes  Origin  Dest
# 0       2017-01-17        1  2017      1  ...       0.0              0.0     CLT   PHX
# 1       2017-01-18        1  2017      1  ...       0.0              0.0     CLT   PHX
# 2       2017-01-19        1  2017      1  ...       0.0              0.0     CLT   PHX
# 3       2017-01-20        1  2017      1  ...       1.0             33.0     CLT   PHX
# 4       2017-01-21        1  2017      1  ...       0.0              2.0     CLT   PHX
# ...            ...      ...   ...    ...  ...       ...              ...     ...   ...
# 458684  2017-09-25        3  2017      9  ...       0.0              0.0     SFO   JFK
# 458687  2017-09-25        3  2017      9  ...       0.0              0.0     EWR   MCO
# 458688  2017-09-25        3  2017      9  ...       0.0              0.0     MCO   EWR
# 458695  2017-09-25        3  2017      9  ...       0.0              0.0     LAS   JFK
# ...

# %%
flight_df=pd.concat([df3_2016,df3_2017])

# %%
flight_df
# Out:
#         FlightDate  Quarter  Year  Month  ...  ArrDel15  ArrDelayMinutes  Origin  Dest
# 57      2016-01-01        1  2016      1  ...       0.0              8.0     SEA   JFK
# 58      2016-01-02        1  2016      1  ...       0.0             11.0     SEA   JFK
# 59      2016-01-03        1  2016      1  ...       0.0              0.0     SEA   JFK
# 60      2016-01-04        1  2016      1  ...       0.0              0.0     SEA   JFK
# 61      2016-01-05        1  2016      1  ...       0.0              0.0     SEA   JFK
# ...            ...      ...   ...    ...  ...       ...              ...     ...   ...
# 458684  2017-09-25        3  2017      9  ...       0.0              0.0     SFO   JFK
# 458687  2017-09-25        3  2017      9  ...       0.0              0.0     EWR   MCO
# 458688  2017-09-25        3  2017      9  ...       0.0              0.0     MCO   EWR
# 458695  2017-09-25        3  2017      9  ...       0.0              0.0     LAS   JFK
# ...

# %%
flight_df.to_csv('/content/gdrive/My Drive/flightdetails.csv')
