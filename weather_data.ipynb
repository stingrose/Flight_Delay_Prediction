# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
import os
data = pd.read_csv('weather/weatherlist.txt', sep=",", header=None,delim_whitespace=True)
data=data.transpose()

# %%
x=data[0].str.split(',', expand=True)
x=x.transpose()
x
# Out:
#       0
# 0   ATL
# 1   CLT
# 2   DEN
# 3   DFW
# 4   EWR
# 5   IAH
# 6   JFK
# 7   LAS
# 8   LAX
# 9   MCO
# 10  MIA
# 11  ORD
# 12  PHX
# 13  SEA
# 14  SFO

# %%
weatherdf=pd.DataFrame()

type(weatherdf)
# Out:
# pandas.core.frame.DataFrame

# %%
with open('weather/ATL/2016-1.json') as f:
    d = json.load(f)

#lets put the data into a pandas df
#clicking on raw_nyc_phil.json under "Input Files"
#tells us parent node is 'programs'
nycphil = json_normalize(d['data']['weather'])
nycphil.head(5)
# Out:
#                                            astronomy        date  \
# 0  [{'moon_phase': 'Waning Gibbous', 'moonrise': ...  2016-01-01
# 1  [{'moon_phase': 'Last Quarter', 'moonrise': '0...  2016-01-02
# 2  [{'moon_phase': 'Last Quarter', 'moonrise': '0...  2016-01-03
# 3  [{'moon_phase': 'Last Quarter', 'moonrise': '0...  2016-01-04
# 4  [{'moon_phase': 'Waning Crescent', 'moonrise':...  2016-01-05
#
#                                               hourly maxtempC maxtempF  \
# 0  [{'windspeedKmph': '11', 'FeelsLikeF': '46', '...       11       51
# 1  [{'windspeedKmph': '15', 'FeelsLikeF': '34', '...        9       48
# 2  [{'windspeedKmph': '10', 'FeelsLikeF': '37', '...       11       51
# 3  [{'windspeedKmph': '13', 'FeelsLikeF': '37', '...        8       46
# 4  [{'windspeedKmph': '12', 'FeelsLikeF': '28', '...        6       43
#
#   mintempC mintempF sunHour totalSnow_cm uvIndex
# 0        5       42     7.5          0.0       0
# 1        2       35     9.0          0.0       0
# 2        3       38     7.5          0.0       0
# 3       -1       31     9.5          0.0       0
# 4        1       33    10.0          0.0       0

# %%
df=[]
dd=pd.DataFrame()

# %%
for i in x[0]:
    path='weather/'+i
    for j in os.listdir(path):
        if('2016' in j):
            with open('weather/'+i+'/'+j) as f:
                d = json.load(f)
                data = json_normalize(d['data']['weather'])
                data=data[['date','hourly']]
                data['airport']=i
                works_data = json_normalize(data=d['data']['weather'], record_path='hourly', errors='ignore')
                works_data['airport'] =i
                dd=dd.append(works_data)

# %%
finalweatherdata2016=dd[['airport','windspeedKmph','winddirDegree','weatherCode','precipMM','visibility',
'pressure',
'cloudcover',
'DewPointF',
'WindGustKmph',
'tempF',
'WindChillF',
'humidity',
'time']]

# %%
#finalweatherdata2016

# %%
dd2017=pd.DataFrame()
for i in x[0]:
    path='weather/'+i
    for j in os.listdir(path):
        if('2017' in j):
            with open('weather/'+i+'/'+j) as f:
                d = json.load(f)
                data = json_normalize(d['data']['weather'])
                data=data[['date','hourly']]
                data['airport']=i
                works_data = json_normalize(data=d['data']['weather'], record_path='hourly', errors='ignore')
                works_data['airport'] =i
                dd2017=dd2017.append(works_data)

# %%
finalweatherdata2017=dd2017[['airport','windspeedKmph','winddirDegree','weatherCode','precipMM','visibility',
'pressure',
'cloudcover',
'DewPointF',
'WindGustKmph',
'tempF',
'WindChillF',
'humidity',
'time']]

# %%
#finalweatherdata2017

# %%
finalweatherdata=pd.concat([finalweatherdata2016,finalweatherdata2017])

# %%
#finalweatherdata.to_csv("weatherdata.csv")
finalweatherdata
# Out:
#     airport windspeedKmph winddirDegree weatherCode precipMM visibility  \
# 0       ATL            11           318         176      0.1         10
# 1       ATL            13           317         176      0.0         10
# 2       ATL            14           315         122      0.0         10
# 3       ATL            16           314         122      0.0         10
# 4       ATL            17           314         122      0.0         10
# 5       ATL            17           315         122      0.0         10
# 6       ATL            18           315         122      0.0         10
# 7       ATL            18           317         122      0.0         10
# 8       ATL            17           318         122      0.0         10
# 9       ATL            17           319         122      0.0         10
# 10      ATL            17           318         122      0.0         10
# 11      ATL            17           317         122      0.0         10
# 12      ATL            17           317         122      0.0         10
# 13      ATL            17           317         122      0.0         10
# 14      ATL            17           317         122      0.0         10
# 15      ATL            17           317         122      0.0         10
# 16      ATL            17           318         122      0.0         10
# 17      ATL            17           318         122      0.0         10
# 18      ATL            17           319         122      0.0         10
# 19      ATL            17           318         122      0.0         10
# 20      ATL            17           317         122      0.0         10
# 21      ATL            16           316         122      0.0         10
# 22      ATL            16           317         122      0.0         10
# 23      ATL            16           318         122      0.0         10
# 24      ATL            15           319         122      0.0         10
# 25      ATL            16           320         122      0.0         10
# 26      ATL            16           321         116      0.0         10
# 27      ATL            16           322         116      0.0         10
# 28      ATL            16           319         116      0.0         10
# 29      ATL            16           316         122      0.0         10
# ..      ...           ...           ...         ...      ...        ...
# 690     SFO            23           272         122      0.0         10
# 691     SFO            22           271         122      0.0         10
# 692     SFO            21           271         122      0.0         10
# 693     SFO            20           271         122      0.0         10
# 694     SFO            19           271         122      0.0         10
# 695     SFO            18           271         122      0.0         10
# 696     SFO            17           271         122      0.0         10
# 697     SFO            17           273         122      0.0         10
# 698     SFO            16           274         122      0.0         10
# 699     SFO            16           276         122      0.0         10
# 700     SFO            15           283         122      0.0         10
# 701     SFO            14           289         143      0.0         10
# 702     SFO            13           296         143      0.0         10
# 703     SFO            11           302         143      0.0         10
# 704     SFO            10           308         122      0.0         10
# 705     SFO             8           313         122      0.0         10
# 706     SFO            11           310         122      0.0         10
# 707     SFO            13           307         113      0.0         10
# 708     SFO            16           304         113      0.0         10
# 709     SFO            18           299         113      0.0         10
# 710     SFO            21           295         113      0.0         10
# 711     SFO            23           291         113      0.0         10
# 712     SFO            24           292         113      0.0         10
# 713     SFO            25           293         113      0.0         10
# 714     SFO            26           294         113      0.0         10
# 715     SFO            26           296         113      0.0         10
